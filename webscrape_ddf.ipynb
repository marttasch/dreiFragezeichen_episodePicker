# %%
import requests
from bs4 import BeautifulSoup
import json
import re


base_url = "https://dreifragezeichen.de/produktwelt/hoerspiele"  # Replace with the base URL of the audiobook series

# %%
page = requests.get(base_url)
soup = BeautifulSoup(page.content, "html.parser")

max_page = soup.find('ul', class_='pagination').find_all('li')[-2].text
print(f'Amount of Subpages: {max_page}')
# Out:
# Amount of Subpages: 22

# %%
# iterate over each subpage
max_page = 2   # limit pages for testing
episode_list = []
for page in range(1, int(max_page)+1):
    subpage_url = f"{base_url}?page={page}"  # Replace with the subpage URL format
    print(f'\nGetting page {page} ...')
    print(f'\t{subpage_url}')

    response = requests.get(subpage_url)
    soup = BeautifulSoup(response.text, "html.parser", from_encoding="utf-8")
    #soup = BeautifulSoup(response.text, 'html.parser')

    # --- Get all episode cards ---
    # Find all the episode elements on the current subpage
    episode_cards = soup.find_all("div", class_="card-expandable")  # Replace with the appropriate HTML element and class

    # --- Extract episode numbers and links ---
    for episode_card in episode_cards:
        # get episode number
        episode_number = episode_card.find("span", class_="d-block").text   # episode number

        # if 'Folge' not 'Special' or something else, skip
        if 'Folge' in episode_number:
            # if episode number already in list, skip
            if any(d['episode_number'] == episode_number for d in episode_list):
                continue
            
            # --- get episode number, title, description, date, image ---
            dict = {}
            dict['episode_number'] = episode_number.strip('Folge ')  # remove 'Folge ' from episode number

            # episode title
            episode_title = episode_card.find("h3", class_="card-title").text 
            episode_title = episode_title.replace('\n', '').replace('\t', '')      # remove \n and \t
            episode_title = episode_title.strip()                                  # remove leading and trailing whitespaces
            dict['episode_title'] = episode_title

            # episode description
            episode_description = episode_card.find('div', class_='card-expander-content').find('p').text   # episode description
            dict['episode_description'] = episode_description
            
            # episode date
            episode_date = episode_card.find('div', class_='card-expander-content-title').find_all('span', class_='d-inline')[2].text
            date_pattern = re.compile(r'\d{2}\.\d{2}\.\d{4}')   # regex pattern for date
            episode_date = date_pattern.search(episode_date).group()   # get date from string
            dict['episode_date'] = episode_date

            # episode image
            episode_image = episode_card.find('img', class_='product-thumb')['src'] 
            dict['episode_image'] = episode_image

            # episode page
            dict['on_page'] = page


            # --- get all links ---
            episode_socialRow = episode_card.find("div", class_="social-row")  # social row with all links
            episode_allLinks = []
            for link in episode_socialRow.find_all('a'):
                episode_allLinks.append(link.get('href'))

            # sort out the episode link by streaming service
            links = {}
            for link in episode_allLinks:
                if 'spotify' in link:
                    links['spotify'] = link
                elif 'apple' in link:
                    links['apple'] = link
                elif 'amazon' in link:
                    links['amazon'] = link
                elif 'youtube' in link:
                    links['youtube'] = link
                elif 'deezer' in link:
                    links['deezer'] = link
                elif 'horspielplayer' in link:
                    links['horspielplayer'] = link

            # sort links alphabetically by streaming service
            links = dict(sorted(links.items()))
            dict['episode_links'] = links

            # add dict to list
            episode_list.append(dict)
# Out:
# Getting page 1 ...
# 	https://dreifragezeichen.de/produktwelt/hoerspiele?page=1
# c:\Users\Martin\AppData\Local\Programs\Python\Python310\lib\site-packages\bs4\__init__.py:226: UserWarning: You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.
#   warnings.warn("You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.")
# Getting page 2 ...
# 	https://dreifragezeichen.de/produktwelt/hoerspiele?page=2

# %%
# sort dict by episode number
episode_list.sort(key=lambda x: int(x['episode_number']))
# epsidoe list json
episode_list_json = json.dumps(episode_list, indent=4)
#print(episode_list_json)

# write json to file
with open('episode_list.json', 'w') as outfile:
    json.dump(episode_list, outfile, indent=4)

# write json to file as list with name
#with open('episode_list.json', 'w') as outfile:
#    json.dump({'episode_list': episode_list}, outfile, indent=4)

# %%
# pick random episode and print spotify link
import random
random_episode = random.choice(episode_list)
print(f'\nRandom episode: {random_episode["episode_number"]} - {random_episode["episode_title"]}')
print(f'\t{random_episode["episode_links"]["spotify"]}')
# Out:
# Random episode: Folge 18 - und die Geisterinsel
# 	https://open.spotify.com/album/1yqICFWBL4l7fJkrFWvfWL

# %%
# download all images from cdn in episode_list and save to folder
import os
import urllib.request
import json
import requests
import shutil

# import episode list
with open('episode_list.json') as json_file:
    episode_list = json.load(json_file)


# create folder if not exists
folder = 'images'
if not os.path.exists(folder):
    os.makedirs(folder)

# download images
for episode in episode_list:
    image_url = episode['episode_image']
    image_name = image_url.split('/')[-1]

    # add https to image url
    if not image_url.startswith('https:'):
        image_url = 'https:' + image_url

    res = requests.get(image_url, stream=True)

    if res.status_code == 200:
        with open(f'{folder}/{image_name}', 'wb') as f:
            shutil.copyfileobj(res.raw, f)
            print('Image sucessfully Downloaded: ', image_name)
    else:
        print('Image Couldn\'t be retreived', image_name)



print('\nDone.')
# Out:
# Image sucessfully Downloaded:  6099922_cover.jpeg
# Image sucessfully Downloaded:  ddf_cd_001.jpg
# Image sucessfully Downloaded:  6099923_cover.jpeg
# Image sucessfully Downloaded:  ddf_cd_002.jpg
# Image sucessfully Downloaded:  6099924_cover.jpeg
# Image sucessfully Downloaded:  ddf_cd_003.jpg
# Image sucessfully Downloaded:  6099925_cover.jpeg
# Image sucessfully Downloaded:  ddf_cd_004.jpg
# Image sucessfully Downloaded:  6099926_cover.jpeg
# Image sucessfully Downloaded:  ddf_cd_005.jpg
# Image sucessfully Downloaded:  ddf_cd_006.jpg
# Image sucessfully Downloaded:  ddf_cd_007.jpg
# Image sucessfully Downloaded:  ddf_cd_008.jpg
# Image sucessfully Downloaded:  ddf_cd_009.jpg
# Image sucessfully Downloaded:  ddf_cd_010.jpg
# Image sucessfully Downloaded:  ddf_cd_011.jpg
# Image sucessfully Downloaded:  ddf_cd_012.jpg
# Image sucessfully Downloaded:  ddf_cd_013.jpg
# Image sucessfully Downloaded:  ddf_cd_014.jpg
# Image sucessfully Downloaded:  ddf_cd_015.jpg
# Image sucessfully Downloaded:  ddf_cd_016.jpg
# Image sucessfully Downloaded:  ddf_cd_017.jpg
# Image sucessfully Downloaded:  ddf_cd_018.jpg
# Image sucessfully Downloaded:  ddf_cd_019.jpg
# Image sucessfully Downloaded:  ddf_cd_020.jpg
# Image sucessfully Downloaded:  ddf_cd_021.jpg
# Image sucessfully Downloaded:  ddf_cd_022.jpg
# Image sucessfully Downloaded:  ddf_cd_023.jpg
# Image sucessfully Downloaded:  ddf_cd_024.jpg
# Image sucessfully Downloaded:  ddf_cd_025.jpg
# Image sucessfully Downloaded:  ddf_cd_026.jpg
# Image sucessfully Downloaded:  ddf_cd_027.jpg
# Image sucessfully Downloaded:  ddf_cd_028.jpg
# Image sucessfully Downloaded:  ddf_cd_029.jpg
# Image sucessfully Downloaded:  ddf_cd_030.jpg
# Image sucessfully Downloaded:  ddf_cd_031.jpg
# Image sucessfully Downloaded:  ddf_cd_032.jpg
# Image sucessfully Downloaded:  ddf_cd_033.jpg
# Image sucessfully Downloaded:  ddf_cd_034.jpg
# Image sucessfully Downloaded:  ddf_cd_035.jpg
# Image sucessfully Downloaded:  ddf_cd_036.jpg
# Image sucessfully Downloaded:  ddf_cd_037.jpg
# Image sucessfully Downloaded:  ddf_cd_038.jpg
# Image sucessfully Downloaded:  ddf_cd_039.jpg
# Image sucessfully Downloaded:  ddf_cd_040.jpg
# Image sucessfully Downloaded:  ddf_cd_041.jpg
# Image sucessfully Downloaded:  ddf_cd_042.jpg
# Image sucessfully Downloaded:  ddf_cd_043.jpg
# Image sucessfully Downloaded:  ddf_cd_044.jpg
# Image sucessfully Downloaded:  ddf_cd_045.jpg
# Image sucessfully Downloaded:  ddf_cd_046.jpg
# Image sucessfully Downloaded:  ddf_cd_047.jpg
# Image sucessfully Downloaded:  ddf_cd_048.jpg
# Image sucessfully Downloaded:  ddf_cd_049.jpg
# Image sucessfully Downloaded:  ddf_cd_050.jpg
# Image sucessfully Downloaded:  ddf_cd_051.jpg
# Image sucessfully Downloaded:  ddf_cd_052.jpg
# Image sucessfully Downloaded:  ddf_cd_053.jpg
# Image sucessfully Downloaded:  ddf_cd_054.jpg
# Image sucessfully Downloaded:  ddf_cd_055.jpg
# Image sucessfully Downloaded:  ddf_cd_056.jpg
# Image sucessfully Downloaded:  ddf_cd_057.jpg
# Image sucessfully Downloaded:  ddf_cd_058.jpg
# Image sucessfully Downloaded:  ddf_cd_059.jpg
# Image sucessfully Downloaded:  ddf_cd_060.jpg
# Image sucessfully Downloaded:  ddf_cd_061.jpg
# Image sucessfully Downloaded:  ddf_cd_062.jpg
# Image sucessfully Downloaded:  ddf_cd_063.jpg
# Image sucessfully Downloaded:  ddf_cd_064.jpg
# Image sucessfully Downloaded:  ddf_cd_065.jpg
# Image sucessfully Downloaded:  ddf_cd_066.jpg
# Image sucessfully Downloaded:  ddf_cd_067.jpg
# Image sucessfully Downloaded:  ddf_cd_068.jpg
# Image sucessfully Downloaded:  ddf_cd_069.jpg
# Image sucessfully Downloaded:  ddf_cd_070.jpg
# Image sucessfully Downloaded:  ddf_cd_071.jpg
# Image sucessfully Downloaded:  ddf_cd_072.jpg
# Image sucessfully Downloaded:  ddf_cd_073.jpg
# Image sucessfully Downloaded:  ddf_cd_074.jpg
# Image sucessfully Downloaded:  ddf_cd_075.jpg
# Image sucessfully Downloaded:  ddf_cd_076.jpg
# Image sucessfully Downloaded:  ddf_cd_077.jpg
# Image sucessfully Downloaded:  ddf_cd_078.jpg
# Image sucessfully Downloaded:  ddf_cd_079.jpg
# Image sucessfully Downloaded:  ddf_cd_080.jpg
# Image sucessfully Downloaded:  ddf_cd_081.jpg
# Image sucessfully Downloaded:  ddf_cd_083.jpg
# Image sucessfully Downloaded:  ddf_cd_084.jpg
# Image sucessfully Downloaded:  ddf_cd_085.jpg
# Image sucessfully Downloaded:  ddf_cd_086.jpg
# Image sucessfully Downloaded:  ddf_cd_087.jpg
# Image sucessfully Downloaded:  ddf_cd_088.jpg
# Image sucessfully Downloaded:  ddf_cd_089.jpg
# Image sucessfully Downloaded:  ddf_cd_090.jpg
# Image sucessfully Downloaded:  ddf_cd_091.jpg
# Image sucessfully Downloaded:  ddf_cd_092.jpg
# Image sucessfully Downloaded:  ddf_cd_093.jpg
# Image sucessfully Downloaded:  ddf_cd_094.jpg
# Image sucessfully Downloaded:  ddf_cd_095.jpg
# Image sucessfully Downloaded:  ddf_cd_096.jpg
# Image sucessfully Downloaded:  ddf_cd_097.jpg
# Image sucessfully Downloaded:  ddf_cd_098.jpg
# Image sucessfully Downloaded:  ddf_cd_099.jpg
# Image sucessfully Downloaded:  ddf_cd_100.jpg
# Image sucessfully Downloaded:  ddf_cd_101.jpg
# Image sucessfully Downloaded:  ddf_cd_102.jpg
# Image sucessfully Downloaded:  ddf_cd_103.jpg
# Image sucessfully Downloaded:  ddf_cd_104.jpg
# Image sucessfully Downloaded:  ddf_cd_105.jpg
# Image sucessfully Downloaded:  ddf_cd_106.jpg
# Image sucessfully Downloaded:  ddf_cd_107.jpg
# Image sucessfully Downloaded:  ddf_cd_108.jpg
# Image sucessfully Downloaded:  ddf_cd_109.jpg
# Image sucessfully Downloaded:  ddf_cd_110.jpg
# Image sucessfully Downloaded:  ddf_cd_111.jpg
# Image sucessfully Downloaded:  ddf_cd_112.jpg
# Image sucessfully Downloaded:  ddf_cd_113.jpg
# Image sucessfully Downloaded:  ddf_cd_114.jpg
# Image sucessfully Downloaded:  ddf_cd_115.jpg
# Image sucessfully Downloaded:  ddf_cd_116.jpg
# Image sucessfully Downloaded:  ddf_cd_117.jpg
# Image sucessfully Downloaded:  ddf_cd_118.jpg
# Image sucessfully Downloaded:  ddf_cd_119.jpg
# Image sucessfully Downloaded:  ddf_cd_120.jpg
# Image sucessfully Downloaded:  ddf_cd_121.jpg
# Image sucessfully Downloaded:  ddf_cd_122.jpg
# Image sucessfully Downloaded:  ddf_cd_123.jpg
# Image sucessfully Downloaded:  ddf_cd_124.jpg
# Image sucessfully Downloaded:  ddf_cd_125.jpg
# Image sucessfully Downloaded:  ddf_cd_126.jpg
# Image sucessfully Downloaded:  ddf_cd_127.jpg
# Image sucessfully Downloaded:  ddf_cd_128.jpg
# Image sucessfully Downloaded:  ddf_cd_129.jpg
# Image sucessfully Downloaded:  ddf_cd_130.jpg
# Image sucessfully Downloaded:  ddf_cd_131.jpg
# Image sucessfully Downloaded:  ddf_cd_132.jpg
# Image sucessfully Downloaded:  ddf_cd_133.jpg
# Image sucessfully Downloaded:  ddf_cd_134.jpg
# Image sucessfully Downloaded:  ddf_cd_135.jpg
# Image sucessfully Downloaded:  ddf_cd_136.jpg
# Image sucessfully Downloaded:  ddf_cd_137.jpg
# Image sucessfully Downloaded:  ddf_cd_138.jpg
# Image sucessfully Downloaded:  ddf_cd_139.jpg
# Image sucessfully Downloaded:  ddf_cd_140.jpg
# Image sucessfully Downloaded:  ddf_cd_141.jpg
# Image sucessfully Downloaded:  ddf_cd_142.jpg
# Image sucessfully Downloaded:  ddf_cd_143.jpg
# Image sucessfully Downloaded:  ddf_cd_144.jpg
# Image sucessfully Downloaded:  ddf_cd_145.jpg
# Image sucessfully Downloaded:  ddf_cd_146.jpg
# Image sucessfully Downloaded:  ddf_cd_147.jpg
# Image sucessfully Downloaded:  ddf_cd_148.jpg
# Image sucessfully Downloaded:  ddf_cd_149.jpg
# Image sucessfully Downloaded:  ddf_cd_150.jpg
# Image sucessfully Downloaded:  ddf_cd_151.jpg
# Image sucessfully Downloaded:  ddf_cd_152.jpg
# Image sucessfully Downloaded:  ddf_cd_153.jpg
# Image sucessfully Downloaded:  ddf_cd_154.jpg
# Image sucessfully Downloaded:  ddf_cd_155.jpg
# Image sucessfully Downloaded:  ddf_cd_156.jpg
# Image sucessfully Downloaded:  ddf_cd_157.jpg
# Image sucessfully Downloaded:  ddf_cd_158.jpg
# Image sucessfully Downloaded:  ddf_cd_159.jpg
# Image sucessfully Downloaded:  ddf_cd_160.jpg
# Image sucessfully Downloaded:  ddf_cd_161.jpg
# Image sucessfully Downloaded:  ddf_cd_162.jpg
# Image sucessfully Downloaded:  ddf_cd_163.jpg
# Image sucessfully Downloaded:  ddf_cd_164.jpg
# Image sucessfully Downloaded:  ddf_cd_165.jpg
# Image sucessfully Downloaded:  ddf_cd_166.jpg
# Image sucessfully Downloaded:  ddf_cd_167.jpg
# Image sucessfully Downloaded:  5163007_cover.jpeg
# Image sucessfully Downloaded:  5186443_cover.jpeg
# Image sucessfully Downloaded:  5221219_cover.jpeg
# Image sucessfully Downloaded:  5235765_cover.jpeg
# Image sucessfully Downloaded:  5292048_cover.jpeg
# Image sucessfully Downloaded:  5332758_cover.jpeg
# Image sucessfully Downloaded:  5369023_cover.jpeg
# Image sucessfully Downloaded:  5406233_cover.jpeg
# Image sucessfully Downloaded:  5449624_cover.jpeg
# Image sucessfully Downloaded:  ddf_cd_177.jpg
# Image sucessfully Downloaded:  5642486_cover.jpeg
# Image sucessfully Downloaded:  5931744_cover.jpeg
# Image sucessfully Downloaded:  6009994_cover.jpeg
# Image sucessfully Downloaded:  6189634_cover.jpeg
# Image sucessfully Downloaded:  6314038_cover.jpeg
# Image sucessfully Downloaded:  6403498_cover.jpeg
# Image sucessfully Downloaded:  6482771_cover.jpeg
# Image sucessfully Downloaded:  6545496_cover.jpeg
# Image sucessfully Downloaded:  6598004_cover.jpeg
# Image sucessfully Downloaded:  6680192_cover.jpeg
# Image sucessfully Downloaded:  6769778_cover.jpeg
# Image sucessfully Downloaded:  6875199_cover.jpg
# Image sucessfully Downloaded:  6994038_cover.jpeg
# Image sucessfully Downloaded:  7118770_cover.jpeg
# Image sucessfully Downloaded:  7182056_cover.jpeg
# Image sucessfully Downloaded:  7258527_cover.jpeg
# Image sucessfully Downloaded:  7411014_cover.jpeg
# Image sucessfully Downloaded:  ddf_cd_195.jpg
# Image sucessfully Downloaded:  7642751_cover.jpeg
# Image sucessfully Downloaded:  ddf_cd_197.jpg
# Image sucessfully Downloaded:  7770148_cover.jpeg
# Image sucessfully Downloaded:  7856253_cover.jpeg
# Image sucessfully Downloaded:  ddf_cd_200.jpg
# Image sucessfully Downloaded:  ddf_cd_201.jpg
# Image sucessfully Downloaded:  ddf_cd_202.jpg
# Image sucessfully Downloaded:  ddf_cd_203.jpg
# Image sucessfully Downloaded:  ddf_cd_204.jpg
# Image sucessfully Downloaded:  19075987392-de_cover.jpg
# Image sucessfully Downloaded:  ddf_cd_206.jpg
# Image sucessfully Downloaded:  cd_ddf_207.jpg
# Image sucessfully Downloaded:  ddf_cd_208.jpg
# Image sucessfully Downloaded:  ddf_cd_209.jpg
# Image sucessfully Downloaded:  ddf_cd_210.jpg
# Image sucessfully Downloaded:  ddf_cd_211.jpg
# Image sucessfully Downloaded:  ddf_cd_212.jpg
# Image sucessfully Downloaded:  01_ddf_213_cover_digital.jpg
# Image sucessfully Downloaded:  ddf_214_cover.jpg
# Image sucessfully Downloaded:  ddf_215.jpg
# Image sucessfully Downloaded:  01_ddf_216_cover_digital.jpg
# Image sucessfully Downloaded:  01_ddf_217_cover.jpg
# Image sucessfully Downloaded:  01_ddf_218_cover.jpg
# Image sucessfully Downloaded:  01_ddf_219_cover.jpg
# Image sucessfully Downloaded:  01_ddf_220_cover.jpg
# Image sucessfully Downloaded:  01_ddf_221_cover.jpg
# Image sucessfully Downloaded:  ddf-222.jpg
#
# Done.
